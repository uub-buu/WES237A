# %%
import subprocess

number_of_terms = 30
cpu = 0

p = subprocess.Popen(['taskset', '-c', '{}'.format(cpu), 'python3', 'fib.py'], stdout=subprocess.PIPE, stderr=subprocess.PIPE, stdin=subprocess.PIPE)
(out, err) = p.communicate(bytes('{}'.format(number_of_terms), 'utf-8'))

print(out.decode('utf-8'))
print(err.decode('utf-8'))
# Out:
# How many terms? time spent: 0.3191227912902832
